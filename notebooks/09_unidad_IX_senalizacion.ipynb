# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Unidad IX — Señalización
#
# *Notas de Clase 12 · El modelo de Spence, equilibrio separador y agrupador*
#
# ---
#
# Macho-Stadler & Pérez Castrillo, cap. 5 · Spence (1973)
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad **todavía no están redactadas**, de modo que el
# > alcance de abajo es provisorio: sale del programa analítico y de la bibliografía,
# > no de las notas del docente.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clase 12 — 14/10** · Alcance detallado en `docs/teoria/unidad_IX.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. Secuencia temporal y equilibrio bayesiano perfecto
#
# Ahora mueve primero el informado.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. El modelo de Spence
#
# Costo decreciente en el tipo y la condición de cruce único.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. Equilibrio separador
#
# El intervalo de niveles de señal compatibles, y el gráfico canónico con las curvas de indiferencia.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. Equilibrio agrupador y refinamientos
#
# Creencias fuera del equilibrio y el criterio intuitivo de Cho-Kreps.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 5. Bienestar: la señalización quema recursos
#
# Comparación separador / agrupador / información completa, con deslizadores de la proporción de tipos.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Macho-Stadler & Pérez Castrillo, cap. 5 · Spence (1973)
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
