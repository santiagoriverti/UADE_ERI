# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Unidad VI — Introducción a la Información Asimétrica
#
# *Notas de Clase 9 · Contratos, agente-principal y el teorema de Borch revisitado*
#
# ---
#
# Macho-Stadler & Pérez Castrillo, caps. 1–2 · Borch (1962)
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad **todavía no están redactadas**, de modo que el
# > alcance de abajo es provisorio: sale del programa analítico y de la bibliografía,
# > no de las notas del docente.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clase 9 — 23/09** · Alcance detallado en `docs/teoria/unidad_VI.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. Mercados incompletos e información asimétrica
#
# El mapa del bloque: riesgo moral, selección adversa y señalización, con sus secuencias temporales.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. La relación agente-principal
#
# Restricción de participación y restricción de incentivos. La RI es exactamente el costo de la asimetría.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. El modelo básico con información simétrica
#
# El reparto óptimo es el teorema de Borch de la Unidad III: con principal neutral, salario fijo.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. Contratos lineales
#
# El caso CARA-Normal y la fórmula de la participación óptima.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Macho-Stadler & Pérez Castrillo, caps. 1–2 · Borch (1962)
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
