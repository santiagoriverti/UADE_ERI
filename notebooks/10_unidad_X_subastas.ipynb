# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Unidad X — Teoría de Juegos, Subastas y Diseño de Mercados
#
# *Notas de Clases 13 y 14 · Vickrey, equivalencia de recaudación y maldición del ganador*
#
# ---
#
# Vickrey (1961) · Wilson (1969) · Milgrom & Weber (1982)
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad **todavía no están redactadas**, de modo que el
# > alcance de abajo es provisorio: sale del programa analítico y de la bibliografía,
# > no de las notas del docente.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clases 13 y 14 — 21/10 y 28/10** · Alcance detallado en `docs/teoria/unidad_X.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. Parte A — Elementos de teoría de los juegos
#
# Lo mínimo necesario: equilibrio de Nash y equilibrio bayesiano de Nash.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. Parte A — Los cuatro formatos clásicos
#
# Inglesa, holandesa, primer precio y segundo precio.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. Parte A — Vickrey: veracidad en estrategia dominante
#
# La demostración de dos casos, y por qué el resultado no depende de creencias.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. Parte A — Equivalencia de recaudación
#
# **Simulación central**: 100.000 subastas de cada formato deben recaudar lo mismo en promedio. Después, romper la equivalencia con postores aversos y asimétricos.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 5. Parte B — Valores comunes y maldición del ganador
#
# **La simulación más didáctica de la materia**: el beneficio del postor ingenuo se hace más negativo a medida que crece n. Incluye una celda para cargar las ofertas reales de la clase.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 6. Parte B — Milgrom & Weber: afiliación y principio de vinculación
#
# El ranking de recaudación y por qué al vendedor le conviene revelar información.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 7. Parte B — Diseño de mercados
#
# Espectro radioeléctrico, publicidad online y mecanismos de reputación, que cierran el círculo con la Unidad VIII.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Vickrey (1961) · Wilson (1969) · Milgrom & Weber (1982)
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
