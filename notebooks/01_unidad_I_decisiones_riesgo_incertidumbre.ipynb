# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Unidad I — Decisiones bajo Riesgo e Incertidumbre
#
# *Notas de Clase 1 · Criterios de decisión, utilidad esperada y Teoría de las Perspectivas*
#
# ---
#
# Kahneman & Tversky (1979) · Gravelle & Rees, cap. 17
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad ya están escritas (`latex/`), pero el desarrollo
# > en Python todavía no. La estructura de abajo marca las secciones previstas.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clase 1 — 05/08** · Alcance detallado en `docs/teoria/unidad_I.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. Riesgo, incertidumbre y la formalización de la decisión
#
# La distinción de Knight. Estados del mundo, prospectos y probabilidades.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. Decisión bajo incertidumbre sin probabilidades
#
# Maximin, maximax, Hurwicz, Laplace y minimax-arrepentimiento sobre la matriz de pagos del ejemplo. Tabla comparativa con `eri.tabla_criterios` y deslizador del coeficiente de optimismo.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. El modelo normativo: la utilidad esperada
#
# Axiomas de vNM, equivalente cierto, prima de riesgo y la figura de la función cóncava con la cuerda.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. La crítica descriptiva: Teoría de las Perspectivas
#
# Efecto certeza (Allais), efecto reflejo y efecto aislamiento. Función de valor en S y función de ponderación.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 5. Cisnes negros y sesgos de optimismo
#
# Comparación de colas: normal contra Pareto con la misma varianza, y qué fracción del total aportan los peores eventos.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Ejercicios resueltos
#
# Los **6 ejercicios** de la guía de esta clase, cada uno con su `assert` de verificación contra la solución analítica.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Kahneman & Tversky (1979) · Gravelle & Rees, cap. 17
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
