# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Unidad V — La Firma Competitiva bajo Incertidumbre
#
# *Notas de Clase 5 · El modelo de Sandmo y la firma tipo Markowitz*
#
# ---
#
# Sandmo (1971)
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad ya están escritas (`latex/`), pero el desarrollo
# > en Python todavía no. La estructura de abajo marca las secciones previstas.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clase 5 — 02/09** · Alcance detallado en `docs/teoria/unidad_V.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. De la certeza a la incertidumbre de precios
#
# El cambio en el orden temporal: la firma decide antes de conocer el precio.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. La firma neutral al riesgo
#
# El caso de referencia: la varianza del precio no interviene.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. El resultado central de Sandmo
#
# Demostración de que el costo marginal óptimo queda por debajo del precio esperado, y verificación Monte Carlo con distribuciones muy distintas.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. La firma con función de utilidad tipo Markowitz
#
# Forma cerrada, estática comparada y deslizadores de sigma cuadrado y de la aversión.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 5. Estática comparada: costos fijos e impuestos
#
# Por qué el signo depende de la *forma* de la aversión (DARA/CARA/IARA), no de su nivel.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 6. Beneficios, entrada y equilibrio de largo plazo
#
# El precio esperado debe superar al costo medio: el beneficio como retribución al riesgo.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Ejercicios resueltos
#
# Los **6 ejercicios** de la guía de esta clase, cada uno con su `assert` de verificación contra la solución analítica.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Sandmo (1971)
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
