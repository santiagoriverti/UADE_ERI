# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Unidad VIII — Selección Adversa
#
# *Notas de Clase 11 · El mercado de limones, menús de contratos y renta informacional*
#
# ---
#
# Macho-Stadler & Pérez Castrillo, cap. 4 · Akerlof (1970)
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad **todavía no están redactadas**, de modo que el
# > alcance de abajo es provisorio: sale del programa analítico y de la bibliografía,
# > no de las notas del docente.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clase 11 — 07/10** · Alcance detallado en `docs/teoria/unidad_VIII.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. El mercado de limones
#
# Simulación de la iteración precio → calidad media → disposición a pagar, hasta el colapso del mercado.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. La espiral de la muerte en seguros
#
# Simulación de un pool con riesgos heterogéneos y prima única.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. El modelo con dos tipos
#
# Sin distorsión arriba, distorsión hacia abajo del ineficiente, y renta informacional.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. Análisis gráfico y cruce único
#
# La condición de Spence-Mirrlees, que es lo que hace posible separar.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 5. Continuo de tipos e instituciones correctoras
#
# Virtual surplus y el hazard rate inverso; screening, garantías, certificación y obligatoriedad.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Macho-Stadler & Pérez Castrillo, cap. 4 · Akerlof (1970)
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
