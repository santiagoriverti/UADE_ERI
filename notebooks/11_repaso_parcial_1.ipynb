# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Repaso — Primer Parcial (Unidades I a V)
#
# *Clases 6 y 7 · Integración y ejercicios de repaso del bloque de riesgo*
#
# ---
#
# Unidades I a V
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad **todavía no están redactadas**, de modo que el
# > alcance de abajo es provisorio: sale del programa analítico y de la bibliografía,
# > no de las notas del docente.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clases 6 y 7 — 05/09 (sábado virtual) y 09/09** · Alcance detallado en `docs/CONTEXTO.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. Mapa conceptual del bloque de riesgo
#
# El arco completo: de los criterios sin probabilidades a la firma bajo incertidumbre de precios.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. Los seis resultados que hay que saber de memoria
#
# Jensen y la concavidad; la aproximación de Pratt; cobertura total a prima justa; el teorema de Borch y la mutualidad; la ecuación del CAPM; el resultado central de Sandmo.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. Errores frecuentes
#
# Confundir promedio con agregado en la LGN; confundir riesgo total con riesgo sistemático; creer que el costo fijo siempre es irrelevante; usar `pi` para tres cosas distintas.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. Ejercicios integradores
#
# Problemas que cruzan unidades, del estilo del parcial.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 5. Simulacro de parcial
#
# Un examen completo con solución.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Unidades I a V
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
