# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Unidad III — Reparto Óptimo del Riesgo
#
# *Notas de Clase 3 · Derechos contingentes, seguro, fondo común y el teorema de Borch*
#
# ---
#
# Borch (1962) · Gravelle & Rees, cap. 19 · Varian, cap. 11
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad ya están escritas (`latex/`), pero el desarrollo
# > en Python todavía no. La estructura de abajo marca las secciones previstas.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clase 3 — 19/08** · Alcance detallado en `docs/teoria/unidad_III.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. Estados de la naturaleza e ingresos contingentes
#
# El plano de rentas contingentes, la línea de certeza y la recta de apuestas justas.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. La decisión de seguro en detalle
#
# Figura del óptimo con prima justa y con recargo, más un deslizador de la tasa de prima.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. Mercados de derechos contingentes y precios de estado
#
# Valores de Arrow, núcleo estocástico de descuento y valuación de tres activos con el mismo pago esperado.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. Difusión del riesgo: Arrow-Lind
#
# El recargo total cayendo como 1/n y la tabla de precios para n = 1, 10, 100.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 5. Fondo común, diversificación y Ley de Grandes Números
#
# Simulación del pooling para n creciente. **La figura central de la unidad**: la varianza del promedio cae mientras la del agregado sube.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 6. El teorema de Borch
#
# Verificación numérica del reparto lineal CARA contra la solución del planificador, y la caja de Edgeworth con y sin riesgo agregado.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Ejercicios resueltos
#
# Los **9 ejercicios** de la guía de esta clase, cada uno con su `assert` de verificación contra la solución analítica.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Borch (1962) · Gravelle & Rees, cap. 19 · Varian, cap. 11
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
