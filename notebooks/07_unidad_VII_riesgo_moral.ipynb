# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Unidad VII — Riesgo Moral
#
# *Notas de Clase 10 · Acción oculta, cociente de verosimilitud y estructura salarial*
#
# ---
#
# Macho-Stadler & Pérez Castrillo, cap. 3 · Holmström (1979)
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad **todavía no están redactadas**, de modo que el
# > alcance de abajo es provisorio: sale del programa analítico y de la bibliografía,
# > no de las notas del docente.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clase 10 — 30/09** · Alcance detallado en `docs/teoria/unidad_VII.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. Secuencia temporal y el modelo con dos esfuerzos
#
# Primer óptimo con esfuerzo observable frente al segundo óptimo.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. Resolución y el cociente de verosimilitud
#
# La condición de Holmström resuelta numéricamente y verificada punto por punto.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. El salario no premia el resultado, premia la evidencia
#
# Gráfico del salario contra el cociente de verosimilitud, y el contraejemplo de no monotonía sin MLRP.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. El enfoque de primer orden y sus condiciones
#
# Cuándo el atajo matemático es válido.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 5. Riesgo moral con información oculta y valor de la información
#
# Principio de revelación; costo de la asimetría contra la aversión del agente.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Macho-Stadler & Pérez Castrillo, cap. 3 · Holmström (1979)
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
