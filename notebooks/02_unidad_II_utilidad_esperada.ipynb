# %% [markdown]
# <div align="center">
#
# **UADE — Facultad de Ciencias Económicas**
#
# **Economía del Riesgo y de la Información (1.4.010) — 2.º cuatrimestre 2026**
#
# # Unidad II — Utilidad Esperada y Aversión al Riesgo
#
# *Notas de Clase 2 · Bernoulli, von Neumann-Morgenstern, Arrow-Pratt y las paradojas*
#
# ---
#
# Varian, cap. 11 · Gravelle & Rees, cap. 17
#
# </div>

# %% [markdown]
# > 🚧 **Notebook en construcción.**
# > Las notas de clase de esta unidad ya están escritas (`latex/`), pero el desarrollo
# > en Python todavía no. La estructura de abajo marca las secciones previstas.
# >
# > El notebook de la **[Unidad IV](https://colab.research.google.com/github/santiagoriverti/UADE_ERI/blob/main/notebooks/04_unidad_IV_finanzas.ipynb)** es el molde a seguir.
#
# ## Qué va a haber acá
#
# **Clase 2 — 12/08** · Alcance detallado en `docs/teoria/unidad_II.md` del repositorio.

# %%
# @title Setup — ejecutá esta celda primero  { display-mode: "form" }
# !wget -q -O eri_utils.py https://raw.githubusercontent.com/santiagoriverti/UADE_ERI/main/src/eri_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import eri_utils as eri

eri.estilo_uade()
SEMILLA = 1410
rng = np.random.default_rng(SEMILLA)

print("Listo. eri_utils", eri.__version__)

# %% [markdown]
# ## 1. El principio de Bernoulli y la paradoja de San Petersburgo
#
# Divergencia del valor esperado, resolución logarítmica y simulación Monte Carlo de la media acumulada, que nunca converge.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 2. Loterías y el teorema de von Neumann-Morgenstern
#
# Los cuatro axiomas, la construcción de la representación y la cardinalidad (contraejemplo con u al cubo).
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 3. Preferencias y aversión al riesgo
#
# Jensen, equivalente cierto y prima de riesgo. Figura de la cuerda con la llave de la prima.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 4. Medidas de aversión al riesgo
#
# Arrow-Pratt absoluta y relativa, aproximación local de Pratt, familias CARA y CRRA, teorema de Pratt y el caso CARA-Normal.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 5. Aplicación: demanda de seguro
#
# Cobertura total a prima justa y parcial con recargo.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## 6. Crítica al modelo tradicional: Allais y Ellsberg
#
# Qué axioma rompe cada una: independencia y existencia de probabilidad subjetiva.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Ejercicios resueltos
#
# Los **10 ejercicios** de la guía de esta clase, cada uno con su `assert` de verificación contra la solución analítica.
#
# *Pendiente de desarrollo.*

# %% [markdown]
# ## Síntesis
#
# *Pendiente de desarrollo.*
#
# ## Referencias
#
# Varian, cap. 11 · Gravelle & Rees, cap. 17
#
# ---
#
# <div align="center">
# <sub>Economía del Riesgo y de la Información (1.4.010) — UADE FCE — 2.º cuatrimestre 2026</sub><br>
# <sub><a href="https://github.com/santiagoriverti/UADE_ERI">github.com/santiagoriverti/UADE_ERI</a></sub>
# </div>
